# %% [markdown]
# <a href="https://colab.research.google.com/github/jul1andav1d/Practice-and-Exercises/blob/main/CORE_Recreate_graph_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
path = '/content/drive/MyDrive/Colab Notebooks/DataSci Week 2 Underst Data/mortgages.csv'
dt = pd.read_csv(path)
dt
# Out:
#       Month  Starting Balance  ...  Mortgage Name  Interest Rate
# 0         1         400000.00  ...        30 Year           0.03
# 1         2         399313.58  ...        30 Year           0.03
# 2         3         398625.44  ...        30 Year           0.03
# 3         4         397935.58  ...        30 Year           0.03
# 4         5         397243.99  ...        30 Year           0.03
# ...     ...               ...  ...            ...            ...
# 1075    176          15619.91  ...        15 Year           0.05
# 1076    177          12521.82  ...        15 Year           0.05
# 1077    178           9410.82  ...        15 Year           0.05
# 1078    179           6286.86  ...        15 Year           0.05
# 1079    180           3149.88  ...        15 Year           0.05
#
# [1080 rows x 8 columns]

# %%
mortgagefilt = dt['Mortgage Name'] == '30 Year'
interestfilt3 =  dt['Interest Rate'] == 0.03
interestfilt5 = dt['Interest Rate'] == 0.05

# %%
mortgagefilt5 = dt.loc[mortgagefilt & interestfilt5]
mortgagefilt3 = dt.loc[mortgagefilt & interestfilt3]

# %%
fig, ax = plt.subplots()
plt.style.use('seaborn')
ax.plot(mortgagefilt3['Month'], mortgagefilt3['Interest Paid'].cumsum(), c = 'g', label = '3 % Interest')
ax.plot(mortgagefilt5['Month'], mortgagefilt5['Interest Paid'].cumsum(), c = 'r', label = '5 % Interest')
plt.title('Cumulative Interest Paid Over 30 Year Loan', fontsize = 20)
plt.xlabel('Month', fontsize = 17)
plt.ylabel('Dollar Amount', fontsize = 17)
plt.xticks(fontsize = 13) and plt.yticks(fontsize = 13)
plt.legend(loc = (0.7,0.1));
plt.show()
